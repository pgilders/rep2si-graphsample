# %% [markdown]
# # REP2SI Regular Graph Extractor
#
# ### Problem statement
# * Given a directed graph `G`, find a subgraph `H` that is a directed regular graph (equal in-degree and out-degree) of degree `k` with all the same nodes as `G`.
#
# ### General approach
# * Some edges in `G` are more important to include (even necessary) in `H` than others in order to find a valid solution.
# * We assign each edge in `G` a score, based on the desired degree `k`, the current in/out-degree of the nodes it connects in `H`, and the in/out degree in `G`.
# * Add edges from `G` to `H`, roughly in order of decreasing score (with some added randomness / reassignment to avoid getting stuck with non-solutions), recalculating scores after each step, until `H` is a regular graph of degree `k`.

# %% [markdown]
# ### Demo implementation
#
# * Generate some random graphs
# * First graphs are generated by creating a regular graph of degree `j` and then adding edges such that each node has out-degree `l` according to preferential attachment.
# * Next graphs are generated by preferential attachment where each node has out-degree `l`, but with rewiring such that each node has minimum in-degree `j`. Here there is not a guarantee that a regular subgraph exists.
# * The function `extract_regular_subgraph` takes a graph `G` and a desired degree `k` and attempts to find a subgraph `H` of `G` that is a regular graph of degree `k`.
# * The function `extract_regular_subgraph` is called on each of the generated graphs, for `k` between 1 and `j/2`, and results stored.

# %%
from subgrapher import *

# Generate some random graphs

# generate regular digraph first, add edges by PA after
G1 = regular_digraph_plus_pa(100, 5, 10)
G2 = regular_digraph_plus_pa(400, 10, 30)

# generate PA with outdegree fixed, rewire to get min in-degree
G3 = random_network_fixed_outdegree(100, 10, 5)
G4 = random_network_fixed_outdegree(400, 30, 10)

# %%
# dictionaries with graphs, to record succcess/failure, and to store results
original_graphs = {'regular_pa_100_5':G1, 'regular_pa_400_10':G2, 'random_fixed_100_5': G3,
          'random_fixed_400_10':G4}
success = {'regular_pa_100_5':{}, 'regular_pa_400_10':{}, 'random_fixed_100_5': {},
            'random_fixed_400_10':[]}
results = {'regular_pa_100_5':{}, 'regular_pa_400_10':{}, 'random_fixed_100_5': {},
            'random_fixed_400_10':{}}

# iterate through graphs
# this takes a while on the larger graphs and larger n, be patient / edit as necessary
for k, g in original_graphs.items():
    print('Graph %s:' %k, g.number_of_nodes(), g.number_of_edges())
    # extract subgraphs of increasing degree (up to half the minimum in-degree)
    for n in range(1, min(dict(g.in_degree()).values())//2 + 1):
        print('Extracting subgraph of fixed node degree %d from %s' %(n, k))
        try:
            subgraph = extract_regular_subgraph(g, n) # extract subgraph
            success[k][n] = True # record success
            results[k][n] = subgraph # store subgraph
        except Exception as e: # if extraction fails, record failure
            print(e)
            success[k][n] = False
            results[k][n] = None

print(success)
# Out:
# Graph regular_pa_100_5: 100 1000
# Extracting subgraph of fixed node degree 1 from regular_pa_100_5
# Shuffling 1 at 1.00%. 96/100 edges assigned
# Shuffling 2 at 1.01%. 96/100 edges assigned
# Shuffling 3 at 1.02%. 96/100 edges assigned
# Shuffling 4 at 1.03%. 96/100 edges assigned
# Shuffling 5 at 1.04%. 96/100 edges assigned
# Shuffling 6 at 1.05%. 96/100 edges assigned
# Shuffling 7 at 1.06%. 96/100 edges assigned
# Shuffling 8 at 1.07%. 96/100 edges assigned
# Shuffling 9 at 1.08%. 96/100 edges assigned
# Shuffling 10 at 1.00%. 96/100 edges assigned
# Shuffling 11 at 1.01%. 96/100 edges assigned
# Shuffling 12 at 1.02%. 96/100 edges assigned
# Shuffling 13 at 1.03%. 96/100 edges assigned
# Shuffling 14 at 1.04%. 96/100 edges assigned
# Shuffling 15 at 1.05%. 96/100 edges assigned
# Shuffling 16 at 1.06%. 96/100 edges assigned
# Shuffling 17 at 1.07%. 96/100 edges assigned
# Shuffling 18 at 1.00%. 98/100 edges assigned
# Shuffling 19 at 1.01%. 98/100 edges assigned
# Shuffling 20 at 1.02%. 98/100 edges assigned
# Shuffling 21 at 1.03%. 98/100 edges assigned
# Shuffling 22 at 1.04%. 98/100 edges assigned
# Shuffling 23 at 1.05%. 98/100 edges assigned
# Shuffling 24 at 1.06%. 98/100 edges assigned
# Shuffling 25 at 1.07%. 98/100 edges assigned
# Shuffling 26 at 1.08%. 98/100 edges assigned
# Shuffling 27 at 1.09%. 98/100 edges assigned
# Shuffling 28 at 1.00%. 98/100 edges assigned
# Shuffling 29 at 1.01%. 98/100 edges assigned
# Shuffling 30 at 1.02%. 98/100 edges assigned
# Shuffling 31 at 1.03%. 98/100 edges assigned
# Shuffling 32 at 1.04%. 98/100 edges assigned
# Shuffling 33 at 1.00%. 98/100 edges assigned
# Shuffling 34 at 1.01%. 98/100 edges assigned
# Shuffling 35 at 1.02%. 98/100 edges assigned
# Shuffling 36 at 1.03%. 98/100 edges assigned
# Shuffling 37 at 1.00%. 98/100 edges assigned
# Shuffling 38 at 1.01%. 98/100 edges assigned
# Shuffling 39 at 1.02%. 98/100 edges assigned
# Shuffling 40 at 1.03%. 98/100 edges assigned
# Shuffling 41 at 1.04%. 98/100 edges assigned
# Shuffling 42 at 1.00%. 98/100 edges assigned
# Shuffling 43 at 1.01%. 98/100 edges assigned
# Shuffling 44 at 1.02%. 98/100 edges assigned
# Shuffling 45 at 1.03%. 98/100 edges assigned
# Shuffling 46 at 1.00%. 99/100 edges assigned
# Shuffling 47 at 1.01%. 99/100 edges assigned
# Shuffling 48 at 1.02%. 99/100 edges assigned
# Shuffling 49 at 1.03%. 99/100 edges assigned
# Shuffling 50 at 1.04%. 99/100 edges assigned
# Shuffling 51 at 1.05%. 99/100 edges assigned
# Shuffling 52 at 1.06%. 99/100 edges assigned
# Shuffling 53 at 1.07%. 99/100 edges assigned
# Shuffling 54 at 1.08%. 99/100 edges assigned
# Shuffling 55 at 1.09%. 99/100 edges assigned
# Shuffling 56 at 1.00%. 99/100 edges assigned
# Shuffling 57 at 1.01%. 99/100 edges assigned
# Shuffling 58 at 1.02%. 99/100 edges assigned
# Shuffling 59 at 1.03%. 99/100 edges assigned
# Shuffling 60 at 1.04%. 99/100 edges assigned
# Shuffling 61 at 1.05%. 99/100 edges assigned
# Shuffling 62 at 1.06%. 99/100 edges assigned
# Shuffling 63 at 1.00%. 99/100 edges assigned
# Shuffling 64 at 1.01%. 99/100 edges assigned
# Shuffling 65 at 1.02%. 99/100 edges assigned
# Shuffling 66 at 1.03%. 99/100 edges assigned
# Shuffling 67 at 1.04%. 99/100 edges assigned
# Shuffling 68 at 1.05%. 99/100 edges assigned
# Shuffling 69 at 1.06%. 99/100 edges assigned
# Shuffling 70 at 1.00%. 99/100 edges assigned
# Shuffling 71 at 1.01%. 99/100 edges assigned
# Shuffling 72 at 1.02%. 99/100 edges assigned
# Shuffling 73 at 1.00%. 99/100 edges assigned
# Shuffling 74 at 1.01%. 99/100 edges assigned
# Shuffling 75 at 1.02%. 99/100 edges assigned
# Shuffling 76 at 1.03%. 99/100 edges assigned
# Shuffling 77 at 1.00%. 99/100 edges assigned
# Shuffling 78 at 1.01%. 99/100 edges assigned
# Shuffling 79 at 1.02%. 99/100 edges assigned
# Shuffling 80 at 1.03%. 99/100 edges assigned
# Shuffling 81 at 1.04%. 99/100 edges assigned
# Shuffling 82 at 1.00%. 99/100 edges assigned
# Shuffling 83 at 1.01%. 99/100 edges assigned
# Shuffling 84 at 1.02%. 99/100 edges assigned
# Shuffling 85 at 1.03%. 99/100 edges assigned
# Solution found
# Subgraph = True
# In degree min = 1, max = 1
# Out degree min = 1, max = 1
# Extracting subgraph of fixed node degree 2 from regular_pa_100_5
# Shuffling 1 at 1.00%. 195/200 edges assigned
# Shuffling 2 at 1.00%. 195/200 edges assigned
# Shuffling 3 at 1.01%. 195/200 edges assigned
# Shuffling 4 at 1.00%. 195/200 edges assigned
# Shuffling 5 at 1.01%. 195/200 edges assigned
# Shuffling 6 at 1.02%. 195/200 edges assigned
# Shuffling 7 at 1.03%. 195/200 edges assigned
# Shuffling 8 at 1.04%. 195/200 edges assigned
# Shuffling 9 at 1.00%. 196/200 edges assigned
# Shuffling 10 at 1.01%. 196/200 edges assigned
# Shuffling 11 at 1.00%. 196/200 edges assigned
# Shuffling 12 at 1.00%. 196/200 edges assigned
# Shuffling 13 at 1.00%. 196/200 edges assigned
# Shuffling 14 at 1.01%. 196/200 edges assigned
# Shuffling 15 at 1.02%. 196/200 edges assigned
# Shuffling 16 at 1.03%. 196/200 edges assigned
# Shuffling 17 at 1.04%. 196/200 edges assigned
# Shuffling 18 at 1.00%. 197/200 edges assigned
# Shuffling 19 at 1.01%. 197/200 edges assigned
# Shuffling 20 at 1.02%. 197/200 edges assigned
# Shuffling 21 at 1.03%. 197/200 edges assigned
# Shuffling 22 at 1.00%. 198/200 edges assigned
# Shuffling 23 at 1.01%. 198/200 edges assigned
# Shuffling 24 at 1.02%. 198/200 edges assigned
# Shuffling 25 at 1.03%. 198/200 edges assigned
# Shuffling 26 at 1.04%. 198/200 edges assigned
# Shuffling 27 at 1.05%. 198/200 edges assigned
# Shuffling 28 at 1.06%. 198/200 edges assigned
# Shuffling 29 at 1.07%. 198/200 edges assigned
# Shuffling 30 at 1.00%. 198/200 edges assigned
# Shuffling 31 at 1.01%. 198/200 edges assigned
# Shuffling 32 at 1.02%. 198/200 edges assigned
# Shuffling 33 at 1.03%. 198/200 edges assigned
# Shuffling 34 at 1.04%. 198/200 edges assigned
# Shuffling 35 at 1.05%. 198/200 edges assigned
# Shuffling 36 at 1.06%. 198/200 edges assigned
# Shuffling 37 at 1.00%. 198/200 edges assigned
# Shuffling 38 at 1.01%. 198/200 edges assigned
# Shuffling 39 at 1.02%. 198/200 edges assigned
# Shuffling 40 at 1.03%. 198/200 edges assigned
# Shuffling 41 at 1.00%. 198/200 edges assigned
# Shuffling 42 at 1.01%. 198/200 edges assigned
# Shuffling 43 at 1.02%. 198/200 edges assigned
# Shuffling 44 at 1.00%. 198/200 edges assigned
# Shuffling 45 at 1.01%. 198/200 edges assigned
# Shuffling 46 at 1.00%. 198/200 edges assigned
# Shuffling 47 at 1.01%. 198/200 edges assigned
# Shuffling 48 at 1.02%. 198/200 edges assigned
# Shuffling 49 at 1.00%. 199/200 edges assigned
# Shuffling 50 at 1.01%. 199/200 edges assigned
# Shuffling 51 at 1.02%. 199/200 edges assigned
# Shuffling 52 at 1.03%. 199/200 edges assigned
# Shuffling 53 at 1.04%. 199/200 edges assigned
# Shuffling 54 at 1.05%. 199/200 edges assigned
# Shuffling 55 at 1.06%. 199/200 edges assigned
# Shuffling 56 at 1.00%. 199/200 edges assigned
# Shuffling 57 at 1.00%. 199/200 edges assigned
# Shuffling 58 at 1.01%. 199/200 edges assigned
# Shuffling 59 at 1.02%. 199/200 edges assigned
# Shuffling 60 at 1.03%. 199/200 edges assigned
# Shuffling 61 at 1.00%. 199/200 edges assigned
# Shuffling 62 at 1.01%. 199/200 edges assigned
# Shuffling 63 at 1.02%. 199/200 edges assigned
# Shuffling 64 at 1.03%. 199/200 edges assigned
# Shuffling 65 at 1.04%. 199/200 edges assigned
# Shuffling 66 at 1.00%. 199/200 edges assigned
# Shuffling 67 at 1.01%. 199/200 edges assigned
# Shuffling 68 at 1.02%. 199/200 edges assigned
# Shuffling 69 at 1.03%. 199/200 edges assigned
# Shuffling 70 at 1.04%. 199/200 edges assigned
# Shuffling 71 at 1.05%. 199/200 edges assigned
# Shuffling 72 at 1.00%. 199/200 edges assigned
# Shuffling 73 at 1.01%. 199/200 edges assigned
# Shuffling 74 at 1.02%. 199/200 edges assigned
# Shuffling 75 at 1.03%. 199/200 edges assigned
# Shuffling 76 at 1.00%. 199/200 edges assigned
# Shuffling 77 at 1.01%. 199/200 edges assigned
# Shuffling 78 at 1.00%. 199/200 edges assigned
# Shuffling 79 at 1.01%. 199/200 edges assigned
# Shuffling 80 at 1.02%. 199/200 edges assigned
# Shuffling 81 at 1.03%. 199/200 edges assigned
# Shuffling 82 at 1.04%. 199/200 edges assigned
# Shuffling 83 at 1.05%. 199/200 edges assigned
# Shuffling 84 at 1.06%. 199/200 edges assigned
# Shuffling 85 at 1.07%. 199/200 edges assigned
# Shuffling 86 at 1.08%. 199/200 edges assigned
# Shuffling 87 at 1.09%. 199/200 edges assigned
# Shuffling 88 at 1.10%. 199/200 edges assigned
# Shuffling 89 at 1.12%. 199/200 edges assigned
# Shuffling 90 at 1.00%. 199/200 edges assigned
# Shuffling 91 at 1.01%. 199/200 edges assigned
# Shuffling 92 at 1.02%. 199/200 edges assigned
# Shuffling 93 at 1.03%. 199/200 edges assigned
# Shuffling 94 at 1.04%. 199/200 edges assigned
# Shuffling 95 at 1.05%. 199/200 edges assigned
# Shuffling 96 at 1.06%. 199/200 edges assigned
# Shuffling 97 at 1.07%. 199/200 edges assigned
# Shuffling 98 at 1.08%. 199/200 edges assigned
# Shuffling 99 at 1.00%. 199/200 edges assigned
# Shuffling 100 at 1.01%. 199/200 edges assigned
# Shuffling 101 at 1.02%. 199/200 edges assigned
# Shuffling 102 at 1.03%. 199/200 edges assigned
# Shuffling 103 at 1.00%. 199/200 edges assigned
# Shuffling 104 at 1.01%. 199/200 edges assigned
# Shuffling 105 at 1.02%. 199/200 edges assigned
# Shuffling 106 at 1.03%. 199/200 edges assigned
# Shuffling 107 at 1.04%. 199/200 edges assigned
# Shuffling 108 at 1.05%. 199/200 edges assigned
# Shuffling 109 at 1.06%. 199/200 edges assigned
# Shuffling 110 at 1.07%. 199/200 edges assigned
# Shuffling 111 at 1.08%. 199/200 edges assigned
# Shuffling 112 at 1.00%. 199/200 edges assigned
# Shuffling 113 at 1.00%. 199/200 edges assigned
# Shuffling 114 at 1.01%. 199/200 edges assigned
# Shuffling 115 at 1.02%. 199/200 edges assigned
# Shuffling 116 at 1.00%. 199/200 edges assigned
# Shuffling 117 at 1.01%. 199/200 edges assigned
# Shuffling 118 at 1.02%. 199/200 edges assigned
# Shuffling 119 at 1.03%. 199/200 edges assigned
# Shuffling 120 at 1.04%. 199/200 edges assigned
# Shuffling 121 at 1.05%. 199/200 edges assigned
# Shuffling 122 at 1.06%. 199/200 edges assigned
# Shuffling 123 at 1.00%. 199/200 edges assigned
# Shuffling 124 at 1.00%. 199/200 edges assigned
# Shuffling 125 at 1.00%. 199/200 edges assigned
# Shuffling 126 at 1.01%. 199/200 edges assigned
# Shuffling 127 at 1.02%. 199/200 edges assigned
# Shuffling 128 at 1.00%. 199/200 edges assigned
# Shuffling 129 at 1.01%. 199/200 edges assigned
# Shuffling 130 at 1.02%. 199/200 edges assigned
# Shuffling 131 at 1.03%. 199/200 edges assigned
# Shuffling 132 at 1.04%. 199/200 edges assigned
# Shuffling 133 at 1.05%. 199/200 edges assigned
# Shuffling 134 at 1.06%. 199/200 edges assigned
# Shuffling 135 at 1.07%. 199/200 edges assigned
# Shuffling 136 at 1.08%. 199/200 edges assigned
# Shuffling 137 at 1.09%. 199/200 edges assigned
# Shuffling 138 at 1.10%. 199/200 edges assigned
# Shuffling 139 at 1.12%. 199/200 edges assigned
# Solution found
# Subgraph = True
# In degree min = 2, max = 2
# Out degree min = 2, max = 2
# Graph regular_pa_400_10: 400 12000
# Extracting subgraph of fixed node degree 1 from regular_pa_400_10
# Shuffling 1 at 1.00%. 395/400 edges assigned
# Shuffling 2 at 1.01%. 395/400 edges assigned
# Shuffling 3 at 1.00%. 396/400 edges assigned
# Shuffling 4 at 1.01%. 396/400 edges assigned
# Shuffling 5 at 1.02%. 396/400 edges assigned
# Shuffling 6 at 1.03%. 396/400 edges assigned
# Shuffling 7 at 1.04%. 396/400 edges assigned
# Shuffling 8 at 1.05%. 396/400 edges assigned
# Shuffling 9 at 1.06%. 396/400 edges assigned
# Shuffling 10 at 1.07%. 396/400 edges assigned
# Shuffling 11 at 1.00%. 397/400 edges assigned
# Shuffling 12 at 1.01%. 397/400 edges assigned
# Shuffling 13 at 1.02%. 397/400 edges assigned
# Shuffling 14 at 1.03%. 397/400 edges assigned
# Shuffling 15 at 1.04%. 397/400 edges assigned
# Shuffling 16 at 1.05%. 397/400 edges assigned
# Shuffling 17 at 1.06%. 397/400 edges assigned
# Shuffling 18 at 1.07%. 397/400 edges assigned
# Shuffling 19 at 1.08%. 397/400 edges assigned
# Shuffling 20 at 1.09%. 397/400 edges assigned
# Shuffling 21 at 1.10%. 397/400 edges assigned
# Shuffling 22 at 1.12%. 397/400 edges assigned
# Shuffling 23 at 1.13%. 397/400 edges assigned
# Shuffling 24 at 1.14%. 397/400 edges assigned
# Shuffling 25 at 1.15%. 397/400 edges assigned
# Shuffling 26 at 1.16%. 397/400 edges assigned
# Shuffling 27 at 1.17%. 397/400 edges assigned
# Shuffling 28 at 1.18%. 397/400 edges assigned
# Shuffling 29 at 1.20%. 397/400 edges assigned
# Shuffling 30 at 1.21%. 397/400 edges assigned
# Shuffling 31 at 1.22%. 397/400 edges assigned
# Shuffling 32 at 1.23%. 397/400 edges assigned
# Shuffling 33 at 1.24%. 397/400 edges assigned
# Shuffling 34 at 1.00%. 397/400 edges assigned
# Shuffling 35 at 1.00%. 397/400 edges assigned
# Shuffling 36 at 1.01%. 397/400 edges assigned
# Shuffling 37 at 1.02%. 397/400 edges assigned
# Shuffling 38 at 1.00%. 397/400 edges assigned
# Shuffling 39 at 1.00%. 397/400 edges assigned
# Shuffling 40 at 1.01%. 397/400 edges assigned
# Shuffling 41 at 1.02%. 397/400 edges assigned
# Shuffling 42 at 1.00%. 397/400 edges assigned
# Shuffling 43 at 1.00%. 398/400 edges assigned
# Shuffling 44 at 1.01%. 398/400 edges assigned
# Shuffling 45 at 1.02%. 398/400 edges assigned
# Shuffling 46 at 1.03%. 398/400 edges assigned
# Shuffling 47 at 1.04%. 398/400 edges assigned
# Shuffling 48 at 1.05%. 398/400 edges assigned
# Shuffling 49 at 1.06%. 398/400 edges assigned
# Shuffling 50 at 1.07%. 398/400 edges assigned
# Shuffling 51 at 1.08%. 398/400 edges assigned
# Shuffling 52 at 1.09%. 398/400 edges assigned
# Shuffling 53 at 1.10%. 398/400 edges assigned
# Shuffling 54 at 1.12%. 398/400 edges assigned
# Shuffling 55 at 1.13%. 398/400 edges assigned
# Shuffling 56 at 1.14%. 398/400 edges assigned
# Shuffling 57 at 1.15%. 398/400 edges assigned
# Shuffling 58 at 1.16%. 398/400 edges assigned
# Shuffling 59 at 1.17%. 398/400 edges assigned
# Shuffling 60 at 1.18%. 398/400 edges assigned
# Shuffling 61 at 1.20%. 398/400 edges assigned
# Shuffling 62 at 1.21%. 398/400 edges assigned
# Shuffling 63 at 1.22%. 398/400 edges assigned
# Shuffling 64 at 1.23%. 398/400 edges assigned
# Shuffling 65 at 1.24%. 398/400 edges assigned
# Shuffling 66 at 1.26%. 398/400 edges assigned
# Shuffling 67 at 1.27%. 398/400 edges assigned
# Shuffling 68 at 1.28%. 398/400 edges assigned
# Shuffling 69 at 1.30%. 398/400 edges assigned
# Shuffling 70 at 1.31%. 398/400 edges assigned
# Shuffling 71 at 1.32%. 398/400 edges assigned
# Shuffling 72 at 1.33%. 398/400 edges assigned
# Shuffling 73 at 1.35%. 398/400 edges assigned
# Shuffling 74 at 1.36%. 398/400 edges assigned
# Shuffling 75 at 1.37%. 398/400 edges assigned
# Shuffling 76 at 1.39%. 398/400 edges assigned
# Shuffling 77 at 1.40%. 398/400 edges assigned
# Shuffling 78 at 1.42%. 398/400 edges assigned
# Shuffling 79 at 1.43%. 398/400 edges assigned
# Shuffling 80 at 1.45%. 398/400 edges assigned
# Shuffling 81 at 1.46%. 398/400 edges assigned
# Shuffling 82 at 1.47%. 398/400 edges assigned
# Shuffling 83 at 1.49%. 398/400 edges assigned
# Shuffling 84 at 1.50%. 398/400 edges assigned
# Shuffling 85 at 1.52%. 398/400 edges assigned
# Shuffling 86 at 1.53%. 398/400 edges assigned
# Shuffling 87 at 1.55%. 398/400 edges assigned
# Shuffling 88 at 1.56%. 398/400 edges assigned
# Shuffling 89 at 1.00%. 399/400 edges assigned
# Shuffling 90 at 1.00%. 399/400 edges assigned
# Shuffling 91 at 1.01%. 399/400 edges assigned
# Shuffling 92 at 1.02%. 399/400 edges assigned
# Shuffling 93 at 1.00%. 399/400 edges assigned
# Shuffling 94 at 1.01%. 399/400 edges assigned
# Shuffling 95 at 1.02%. 399/400 edges assigned
# Shuffling 96 at 1.00%. 399/400 edges assigned
# Shuffling 97 at 1.00%. 399/400 edges assigned
# Shuffling 98 at 1.00%. 399/400 edges assigned
# Shuffling 99 at 1.01%. 399/400 edges assigned
# Shuffling 100 at 1.02%. 399/400 edges assigned
# Shuffling 101 at 1.03%. 399/400 edges assigned
# Shuffling 102 at 1.04%. 399/400 edges assigned
# Shuffling 103 at 1.05%. 399/400 edges assigned
# Shuffling 104 at 1.06%. 399/400 edges assigned
# Shuffling 105 at 1.00%. 399/400 edges assigned
# Shuffling 106 at 1.01%. 399/400 edges assigned
# Shuffling 107 at 1.02%. 399/400 edges assigned
# Shuffling 108 at 1.03%. 399/400 edges assigned
# Shuffling 109 at 1.04%. 399/400 edges assigned
# Shuffling 110 at 1.05%. 399/400 edges assigned
# Shuffling 111 at 1.06%. 399/400 edges assigned
# Shuffling 112 at 1.07%. 399/400 edges assigned
# Shuffling 113 at 1.08%. 399/400 edges assigned
# Shuffling 114 at 1.09%. 399/400 edges assigned
# Shuffling 115 at 1.10%. 399/400 edges assigned
# Shuffling 116 at 1.12%. 399/400 edges assigned
# Shuffling 117 at 1.13%. 399/400 edges assigned
# Shuffling 118 at 1.14%. 399/400 edges assigned
# Shuffling 119 at 1.15%. 399/400 edges assigned
# Shuffling 120 at 1.16%. 399/400 edges assigned
# Shuffling 121 at 1.17%. 399/400 edges assigned
# Shuffling 122 at 1.18%. 399/400 edges assigned
# Shuffling 123 at 1.20%. 399/400 edges assigned
# Shuffling 124 at 1.21%. 399/400 edges assigned
# Shuffling 125 at 1.22%. 399/400 edges assigned
# Shuffling 126 at 1.23%. 399/400 edges assigned
# Shuffling 127 at 1.24%. 399/400 edges assigned
# Shuffling 128 at 1.26%. 399/400 edges assigned
# Shuffling 129 at 1.27%. 399/400 edges assigned
# Shuffling 130 at 1.00%. 399/400 edges assigned
# Shuffling 131 at 1.01%. 399/400 edges assigned
# Shuffling 132 at 1.02%. 399/400 edges assigned
# Shuffling 133 at 1.03%. 399/400 edges assigned
# Shuffling 134 at 1.04%. 399/400 edges assigned
# Shuffling 135 at 1.05%. 399/400 edges assigned
# Shuffling 136 at 1.06%. 399/400 edges assigned
# Shuffling 137 at 1.07%. 399/400 edges assigned
# Shuffling 138 at 1.08%. 399/400 edges assigned
# Shuffling 139 at 1.09%. 399/400 edges assigned
# Shuffling 140 at 1.10%. 399/400 edges assigned
# Shuffling 141 at 1.12%. 399/400 edges assigned
# Shuffling 142 at 1.13%. 399/400 edges assigned
# Shuffling 143 at 1.14%. 399/400 edges assigned
# Shuffling 144 at 1.15%. 399/400 edges assigned
# Shuffling 145 at 1.16%. 399/400 edges assigned
# Shuffling 146 at 1.17%. 399/400 edges assigned
# Shuffling 147 at 1.18%. 399/400 edges assigned
# Shuffling 148 at 1.20%. 399/400 edges assigned
# Shuffling 149 at 1.21%. 399/400 edges assigned
# Shuffling 150 at 1.22%. 399/400 edges assigned
# Shuffling 151 at 1.23%. 399/400 edges assigned
# Shuffling 152 at 1.24%. 399/400 edges assigned
# Shuffling 153 at 1.26%. 399/400 edges assigned
# Shuffling 154 at 1.27%. 399/400 edges assigned
# Shuffling 155 at 1.28%. 399/400 edges assigned
# Shuffling 156 at 1.30%. 399/400 edges assigned
# Shuffling 157 at 1.31%. 399/400 edges assigned
# Shuffling 158 at 1.32%. 399/400 edges assigned
# Shuffling 159 at 1.33%. 399/400 edges assigned
# Shuffling 160 at 1.35%. 399/400 edges assigned
# Shuffling 161 at 1.36%. 399/400 edges assigned
# Shuffling 162 at 1.37%. 399/400 edges assigned
# Shuffling 163 at 1.39%. 399/400 edges assigned
# Shuffling 164 at 1.40%. 399/400 edges assigned
# Shuffling 165 at 1.42%. 399/400 edges assigned
# Shuffling 166 at 1.43%. 399/400 edges assigned
# Shuffling 167 at 1.45%. 399/400 edges assigned
# Shuffling 168 at 1.46%. 399/400 edges assigned
# Shuffling 169 at 1.47%. 399/400 edges assigned
# Shuffling 170 at 1.49%. 399/400 edges assigned
# Shuffling 171 at 1.50%. 399/400 edges assigned
# Shuffling 172 at 1.52%. 399/400 edges assigned
# Shuffling 173 at 1.53%. 399/400 edges assigned
# Shuffling 174 at 1.55%. 399/400 edges assigned
# Shuffling 175 at 1.56%. 399/400 edges assigned
# Shuffling 176 at 1.58%. 399/400 edges assigned
# Shuffling 177 at 1.60%. 399/400 edges assigned
# Shuffling 178 at 1.61%. 399/400 edges assigned
# Shuffling 179 at 1.63%. 399/400 edges assigned
# Shuffling 180 at 1.64%. 399/400 edges assigned
# Shuffling 181 at 1.66%. 399/400 edges assigned
# Shuffling 182 at 1.68%. 399/400 edges assigned
# Shuffling 183 at 1.69%. 399/400 edges assigned
# Shuffling 184 at 1.71%. 399/400 edges assigned
# Shuffling 185 at 1.73%. 399/400 edges assigned
# Shuffling 186 at 1.75%. 399/400 edges assigned
# Shuffling 187 at 1.76%. 399/400 edges assigned
# Shuffling 188 at 1.78%. 399/400 edges assigned
# Shuffling 189 at 1.80%. 399/400 edges assigned
# Shuffling 190 at 1.82%. 399/400 edges assigned
# Shuffling 191 at 1.83%. 399/400 edges assigned
# Shuffling 192 at 1.85%. 399/400 edges assigned
# Shuffling 193 at 1.87%. 399/400 edges assigned
# Shuffling 194 at 1.89%. 399/400 edges assigned
# Shuffling 195 at 1.91%. 399/400 edges assigned
# Shuffling 196 at 1.93%. 399/400 edges assigned
# Shuffling 197 at 1.95%. 399/400 edges assigned
# Shuffling 198 at 1.97%. 399/400 edges assigned
# Shuffling 199 at 1.99%. 399/400 edges assigned
# Shuffling 200 at 2.01%. 399/400 edges assigned
# Shuffling 201 at 2.03%. 399/400 edges assigned
# Shuffling 202 at 2.05%. 399/400 edges assigned
# Shuffling 203 at 2.07%. 399/400 edges assigned
# Shuffling 204 at 2.09%. 399/400 edges assigned
# Shuffling 205 at 2.11%. 399/400 edges assigned
# Shuffling 206 at 2.13%. 399/400 edges assigned
# Shuffling 207 at 2.15%. 399/400 edges assigned
# Shuffling 208 at 2.17%. 399/400 edges assigned
# Shuffling 209 at 2.19%. 399/400 edges assigned
# Shuffling 210 at 2.22%. 399/400 edges assigned
# Shuffling 211 at 2.24%. 399/400 edges assigned
# Shuffling 212 at 2.26%. 399/400 edges assigned
# Shuffling 213 at 2.28%. 399/400 edges assigned
# Shuffling 214 at 2.31%. 399/400 edges assigned
# Shuffling 215 at 2.33%. 399/400 edges assigned
# Shuffling 216 at 2.35%. 399/400 edges assigned
# Shuffling 217 at 2.38%. 399/400 edges assigned
# Shuffling 218 at 2.40%. 399/400 edges assigned
# Shuffling 219 at 2.42%. 399/400 edges assigned
# Shuffling 220 at 2.45%. 399/400 edges assigned
# Shuffling 221 at 2.47%. 399/400 edges assigned
# Shuffling 222 at 2.50%. 399/400 edges assigned
# Shuffling 223 at 2.52%. 399/400 edges assigned
# Shuffling 224 at 2.55%. 399/400 edges assigned
# Shuffling 225 at 2.57%. 399/400 edges assigned
# Shuffling 226 at 2.60%. 399/400 edges assigned
# Shuffling 227 at 2.63%. 399/400 edges assigned
# Shuffling 228 at 2.65%. 399/400 edges assigned
# Shuffling 229 at 2.68%. 399/400 edges assigned
# Shuffling 230 at 2.70%. 399/400 edges assigned
# Shuffling 231 at 2.73%. 399/400 edges assigned
# Shuffling 232 at 2.76%. 399/400 edges assigned
# Shuffling 233 at 2.79%. 399/400 edges assigned
# Shuffling 234 at 2.81%. 399/400 edges assigned
# Shuffling 235 at 2.84%. 399/400 edges assigned
# Shuffling 236 at 1.00%. 399/400 edges assigned
# Shuffling 237 at 1.01%. 399/400 edges assigned
# Shuffling 238 at 1.02%. 399/400 edges assigned
# Shuffling 239 at 1.03%. 399/400 edges assigned
# Shuffling 240 at 1.04%. 399/400 edges assigned
# Shuffling 241 at 1.05%. 399/400 edges assigned
# Shuffling 242 at 1.06%. 399/400 edges assigned
# Shuffling 243 at 1.07%. 399/400 edges assigned
# Shuffling 244 at 1.08%. 399/400 edges assigned
# Shuffling 245 at 1.09%. 399/400 edges assigned
# Shuffling 246 at 1.10%. 399/400 edges assigned
# Shuffling 247 at 1.12%. 399/400 edges assigned
# Shuffling 248 at 1.13%. 399/400 edges assigned
# Shuffling 249 at 1.14%. 399/400 edges assigned
# Shuffling 250 at 1.00%. 399/400 edges assigned
# Shuffling 251 at 1.01%. 399/400 edges assigned
# Shuffling 252 at 1.02%. 399/400 edges assigned
# Shuffling 253 at 1.03%. 399/400 edges assigned
# Shuffling 254 at 1.04%. 399/400 edges assigned
# Shuffling 255 at 1.05%. 399/400 edges assigned
# Shuffling 256 at 1.06%. 399/400 edges assigned
# Shuffling 257 at 1.07%. 399/400 edges assigned
# Shuffling 258 at 1.08%. 399/400 edges assigned
# Shuffling 259 at 1.09%. 399/400 edges assigned
# Shuffling 260 at 1.10%. 399/400 edges assigned
# Shuffling 261 at 1.12%. 399/400 edges assigned
# Shuffling 262 at 1.13%. 399/400 edges assigned
# Shuffling 263 at 1.14%. 399/400 edges assigned
# Shuffling 264 at 1.15%. 399/400 edges assigned
# Shuffling 265 at 1.16%. 399/400 edges assigned
# Shuffling 266 at 1.17%. 399/400 edges assigned
# Shuffling 267 at 1.18%. 399/400 edges assigned
# Shuffling 268 at 1.20%. 399/400 edges assigned
# Shuffling 269 at 1.21%. 399/400 edges assigned
# Shuffling 270 at 1.22%. 399/400 edges assigned
# Shuffling 271 at 1.23%. 399/400 edges assigned
# Shuffling 272 at 1.24%. 399/400 edges assigned
# Shuffling 273 at 1.26%. 399/400 edges assigned
# Shuffling 274 at 1.27%. 399/400 edges assigned
# Shuffling 275 at 1.28%. 399/400 edges assigned
# Shuffling 276 at 1.30%. 399/400 edges assigned
# Shuffling 277 at 1.00%. 399/400 edges assigned
# Shuffling 278 at 1.01%. 399/400 edges assigned
# Shuffling 279 at 1.02%. 399/400 edges assigned
# Shuffling 280 at 1.00%. 399/400 edges assigned
# Shuffling 281 at 1.01%. 399/400 edges assigned
# Shuffling 282 at 1.02%. 399/400 edges assigned
# Shuffling 283 at 1.03%. 399/400 edges assigned
# Shuffling 284 at 1.04%. 399/400 edges assigned
# Shuffling 285 at 1.05%. 399/400 edges assigned
# Shuffling 286 at 1.06%. 399/400 edges assigned
# Shuffling 287 at 1.07%. 399/400 edges assigned
# Shuffling 288 at 1.08%. 399/400 edges assigned
# Shuffling 289 at 1.09%. 399/400 edges assigned
# Shuffling 290 at 1.10%. 399/400 edges assigned
# Shuffling 291 at 1.12%. 399/400 edges assigned
# Shuffling 292 at 1.13%. 399/400 edges assigned
# Shuffling 293 at 1.00%. 399/400 edges assigned
# Shuffling 294 at 1.01%. 399/400 edges assigned
# Shuffling 295 at 1.02%. 399/400 edges assigned
# Shuffling 296 at 1.03%. 399/400 edges assigned
# Shuffling 297 at 1.04%. 399/400 edges assigned
# Shuffling 298 at 1.05%. 399/400 edges assigned
# Shuffling 299 at 1.06%. 399/400 edges assigned
# Shuffling 300 at 1.07%. 399/400 edges assigned
# Shuffling 301 at 1.08%. 399/400 edges assigned
# Shuffling 302 at 1.09%. 399/400 edges assigned
# Shuffling 303 at 1.10%. 399/400 edges assigned
# Shuffling 304 at 1.12%. 399/400 edges assigned
# Shuffling 305 at 1.13%. 399/400 edges assigned
# Shuffling 306 at 1.14%. 399/400 edges assigned
# Shuffling 307 at 1.15%. 399/400 edges assigned
# Shuffling 308 at 1.16%. 399/400 edges assigned
# Shuffling 309 at 1.17%. 399/400 edges assigned
# Shuffling 310 at 1.18%. 399/400 edges assigned
# Shuffling 311 at 1.20%. 399/400 edges assigned
# Shuffling 312 at 1.21%. 399/400 edges assigned
# Shuffling 313 at 1.22%. 399/400 edges assigned
# Shuffling 314 at 1.23%. 399/400 edges assigned
# Shuffling 315 at 1.24%. 399/400 edges assigned
# Shuffling 316 at 1.26%. 399/400 edges assigned
# Shuffling 317 at 1.27%. 399/400 edges assigned
# Shuffling 318 at 1.00%. 399/400 edges assigned
# Shuffling 319 at 1.01%. 399/400 edges assigned
# Shuffling 320 at 1.02%. 399/400 edges assigned
# Shuffling 321 at 1.03%. 399/400 edges assigned
# Shuffling 322 at 1.04%. 399/400 edges assigned
# Shuffling 323 at 1.05%. 399/400 edges assigned
# Shuffling 324 at 1.06%. 399/400 edges assigned
# Shuffling 325 at 1.07%. 399/400 edges assigned
# Shuffling 326 at 1.08%. 399/400 edges assigned
# Shuffling 327 at 1.09%. 399/400 edges assigned
# Shuffling 328 at 1.10%. 399/400 edges assigned
# Shuffling 329 at 1.12%. 399/400 edges assigned
# Shuffling 330 at 1.13%. 399/400 edges assigned
# Shuffling 331 at 1.14%. 399/400 edges assigned
# Shuffling 332 at 1.15%. 399/400 edges assigned
# Shuffling 333 at 1.16%. 399/400 edges assigned
# Shuffling 334 at 1.17%. 399/400 edges assigned
# Shuffling 335 at 1.18%. 399/400 edges assigned
# Shuffling 336 at 1.20%. 399/400 edges assigned
# Shuffling 337 at 1.21%. 399/400 edges assigned
# Shuffling 338 at 1.22%. 399/400 edges assigned
# Shuffling 339 at 1.23%. 399/400 edges assigned
# Shuffling 340 at 1.24%. 399/400 edges assigned
# Shuffling 341 at 1.26%. 399/400 edges assigned
# Shuffling 342 at 1.27%. 399/400 edges assigned
# Shuffling 343 at 1.28%. 399/400 edges assigned
# Shuffling 344 at 1.30%. 399/400 edges assigned
# Shuffling 345 at 1.31%. 399/400 edges assigned
# Shuffling 346 at 1.32%. 399/400 edges assigned
# Shuffling 347 at 1.33%. 399/400 edges assigned
# Shuffling 348 at 1.35%. 399/400 edges assigned
# Shuffling 349 at 1.36%. 399/400 edges assigned
# Shuffling 350 at 1.37%. 399/400 edges assigned
# Shuffling 351 at 1.39%. 399/400 edges assigned
# Shuffling 352 at 1.40%. 399/400 edges assigned
# Shuffling 353 at 1.42%. 399/400 edges assigned
# Shuffling 354 at 1.43%. 399/400 edges assigned
# Shuffling 355 at 1.45%. 399/400 edges assigned
# Shuffling 356 at 1.46%. 399/400 edges assigned
# Shuffling 357 at 1.47%. 399/400 edges assigned
# Shuffling 358 at 1.49%. 399/400 edges assigned
# Shuffling 359 at 1.50%. 399/400 edges assigned
# Shuffling 360 at 1.52%. 399/400 edges assigned
# Shuffling 361 at 1.53%. 399/400 edges assigned
# Shuffling 362 at 1.55%. 399/400 edges assigned
# Shuffling 363 at 1.56%. 399/400 edges assigned
# Shuffling 364 at 1.58%. 399/400 edges assigned
# Shuffling 365 at 1.60%. 399/400 edges assigned
# Shuffling 366 at 1.61%. 399/400 edges assigned
# Shuffling 367 at 1.63%. 399/400 edges assigned
# Shuffling 368 at 1.64%. 399/400 edges assigned
# Shuffling 369 at 1.66%. 399/400 edges assigned
# Shuffling 370 at 1.68%. 399/400 edges assigned
# Shuffling 371 at 1.69%. 399/400 edges assigned
# Shuffling 372 at 1.71%. 399/400 edges assigned
# Shuffling 373 at 1.73%. 399/400 edges assigned
# Shuffling 374 at 1.75%. 399/400 edges assigned
# Shuffling 375 at 1.76%. 399/400 edges assigned
# Shuffling 376 at 1.78%. 399/400 edges assigned
# Shuffling 377 at 1.80%. 399/400 edges assigned
# Shuffling 378 at 1.82%. 399/400 edges assigned
# Shuffling 379 at 1.83%. 399/400 edges assigned
# Shuffling 380 at 1.85%. 399/400 edges assigned
# Shuffling 381 at 1.87%. 399/400 edges assigned
# Shuffling 382 at 1.89%. 399/400 edges assigned
# Shuffling 383 at 1.91%. 399/400 edges assigned
# Shuffling 384 at 1.93%. 399/400 edges assigned
# Shuffling 385 at 1.95%. 399/400 edges assigned
# Shuffling 386 at 1.97%. 399/400 edges assigned
# Shuffling 387 at 1.99%. 399/400 edges assigned
# Shuffling 388 at 2.01%. 399/400 edges assigned
# Shuffling 389 at 2.03%. 399/400 edges assigned
# Shuffling 390 at 2.05%. 399/400 edges assigned
# Shuffling 391 at 2.07%. 399/400 edges assigned
# Shuffling 392 at 2.09%. 399/400 edges assigned
# Shuffling 393 at 2.11%. 399/400 edges assigned
# Shuffling 394 at 2.13%. 399/400 edges assigned
# Shuffling 395 at 2.15%. 399/400 edges assigned
# Shuffling 396 at 2.17%. 399/400 edges assigned
# Shuffling 397 at 2.19%. 399/400 edges assigned
# Shuffling 398 at 2.22%. 399/400 edges assigned
# Shuffling 399 at 2.24%. 399/400 edges assigned
# Shuffling 400 at 2.26%. 399/400 edges assigned
# Shuffling 401 at 2.28%. 399/400 edges assigned
# Shuffling 402 at 2.31%. 399/400 edges assigned
# Shuffling 403 at 2.33%. 399/400 edges assigned
# Shuffling 404 at 2.35%. 399/400 edges assigned
# Shuffling 405 at 2.38%. 399/400 edges assigned
# Shuffling 406 at 2.40%. 399/400 edges assigned
# Shuffling 407 at 2.42%. 399/400 edges assigned
# Shuffling 408 at 2.45%. 399/400 edges assigned
# Shuffling 409 at 2.47%. 399/400 edges assigned
# Shuffling 410 at 2.50%. 399/400 edges assigned
# Shuffling 411 at 2.52%. 399/400 edges assigned
# Shuffling 412 at 2.55%. 399/400 edges assigned
# Shuffling 413 at 2.57%. 399/400 edges assigned
# Shuffling 414 at 2.60%. 399/400 edges assigned
# Shuffling 415 at 2.63%. 399/400 edges assigned
# Shuffling 416 at 2.65%. 399/400 edges assigned
# Shuffling 417 at 2.68%. 399/400 edges assigned
# Shuffling 418 at 2.70%. 399/400 edges assigned
# Shuffling 419 at 2.73%. 399/400 edges assigned
# Shuffling 420 at 2.76%. 399/400 edges assigned
# Shuffling 421 at 2.79%. 399/400 edges assigned
# Shuffling 422 at 2.81%. 399/400 edges assigned
# Shuffling 423 at 2.84%. 399/400 edges assigned
# Shuffling 424 at 2.87%. 399/400 edges assigned
# Shuffling 425 at 2.90%. 399/400 edges assigned
# Shuffling 426 at 2.93%. 399/400 edges assigned
# Shuffling 427 at 2.96%. 399/400 edges assigned
# Shuffling 428 at 2.99%. 399/400 edges assigned
# Shuffling 429 at 3.02%. 399/400 edges assigned
# Shuffling 430 at 3.05%. 399/400 edges assigned
# Shuffling 431 at 3.08%. 399/400 edges assigned
# Shuffling 432 at 3.11%. 399/400 edges assigned
# Shuffling 433 at 3.14%. 399/400 edges assigned
# Shuffling 434 at 3.17%. 399/400 edges assigned
# Shuffling 435 at 3.20%. 399/400 edges assigned
# Shuffling 436 at 3.24%. 399/400 edges assigned
# Shuffling 437 at 3.27%. 399/400 edges assigned
# Shuffling 438 at 3.30%. 399/400 edges assigned
# Shuffling 439 at 3.33%. 399/400 edges assigned
# Shuffling 440 at 3.37%. 399/400 edges assigned
# Shuffling 441 at 3.40%. 399/400 edges assigned
# Shuffling 442 at 3.43%. 399/400 edges assigned
# Shuffling 443 at 3.47%. 399/400 edges assigned
# Shuffling 444 at 3.50%. 399/400 edges assigned
# Shuffling 445 at 3.54%. 399/400 edges assigned
# Shuffling 446 at 3.57%. 399/400 edges assigned
# Shuffling 447 at 3.61%. 399/400 edges assigned
# Shuffling 448 at 3.65%. 399/400 edges assigned
# Shuffling 449 at 3.68%. 399/400 edges assigned
# Shuffling 450 at 3.72%. 399/400 edges assigned
# Shuffling 451 at 3.76%. 399/400 edges assigned
# Shuffling 452 at 3.79%. 399/400 edges assigned
# Shuffling 453 at 3.83%. 399/400 edges assigned
# Shuffling 454 at 3.87%. 399/400 edges assigned
# Shuffling 455 at 3.91%. 399/400 edges assigned
# Shuffling 456 at 3.95%. 399/400 edges assigned
# Shuffling 457 at 3.99%. 399/400 edges assigned
# Shuffling 458 at 4.03%. 399/400 edges assigned
# Shuffling 459 at 4.07%. 399/400 edges assigned
# Shuffling 460 at 4.11%. 399/400 edges assigned
# Shuffling 461 at 4.15%. 399/400 edges assigned
# Shuffling 462 at 4.19%. 399/400 edges assigned
# Shuffling 463 at 4.23%. 399/400 edges assigned
# Shuffling 464 at 4.27%. 399/400 edges assigned
# Shuffling 465 at 4.32%. 399/400 edges assigned
# Shuffling 466 at 4.36%. 399/400 edges assigned
# Shuffling 467 at 4.40%. 399/400 edges assigned
# Shuffling 468 at 4.45%. 399/400 edges assigned
# Shuffling 469 at 4.49%. 399/400 edges assigned
# Shuffling 470 at 4.54%. 399/400 edges assigned
# Shuffling 471 at 4.58%. 399/400 edges assigned
# Shuffling 472 at 4.63%. 399/400 edges assigned
# Shuffling 473 at 4.68%. 399/400 edges assigned
# Shuffling 474 at 4.72%. 399/400 edges assigned
# Shuffling 475 at 4.77%. 399/400 edges assigned
# Shuffling 476 at 4.82%. 399/400 edges assigned
# Shuffling 477 at 4.87%. 399/400 edges assigned
# Shuffling 478 at 4.91%. 399/400 edges assigned
# Shuffling 479 at 4.96%. 399/400 edges assigned
# Shuffling 480 at 5.01%. 399/400 edges assigned
# Shuffling 481 at 5.06%. 399/400 edges assigned
# Shuffling 482 at 5.11%. 399/400 edges assigned
# Shuffling 483 at 5.16%. 399/400 edges assigned
# Shuffling 484 at 5.22%. 399/400 edges assigned
# Shuffling 485 at 5.27%. 399/400 edges assigned
# Shuffling 486 at 5.32%. 399/400 edges assigned
# Shuffling 487 at 5.37%. 399/400 edges assigned
# Shuffling 488 at 5.43%. 399/400 edges assigned
# Shuffling 489 at 5.48%. 399/400 edges assigned
# Shuffling 490 at 5.54%. 399/400 edges assigned
# Shuffling 491 at 5.59%. 399/400 edges assigned
# Shuffling 492 at 5.65%. 399/400 edges assigned
# Shuffling 493 at 5.70%. 399/400 edges assigned
# Shuffling 494 at 5.76%. 399/400 edges assigned
# Shuffling 495 at 5.82%. 399/400 edges assigned
# Shuffling 496 at 5.88%. 399/400 edges assigned
# Shuffling 497 at 5.94%. 399/400 edges assigned
# Shuffling 498 at 6.00%. 399/400 edges assigned
# Shuffling 499 at 6.06%. 399/400 edges assigned
# Shuffling 500 at 6.12%. 399/400 edges assigned
# Shuffling 501 at 1.00%. 399/400 edges assigned
# Shuffling 502 at 1.01%. 399/400 edges assigned
# Shuffling 503 at 1.02%. 399/400 edges assigned
# Shuffling 504 at 1.03%. 399/400 edges assigned
# Shuffling 505 at 1.04%. 399/400 edges assigned
# Shuffling 506 at 1.05%. 399/400 edges assigned
# Shuffling 507 at 1.00%. 399/400 edges assigned
# Shuffling 508 at 1.01%. 399/400 edges assigned
# Shuffling 509 at 1.02%. 399/400 edges assigned
# Shuffling 510 at 1.03%. 399/400 edges assigned
# Shuffling 511 at 1.04%. 399/400 edges assigned
# Shuffling 512 at 1.05%. 399/400 edges assigned
# Shuffling 513 at 1.06%. 399/400 edges assigned
# Shuffling 514 at 1.07%. 399/400 edges assigned
# Shuffling 515 at 1.08%. 399/400 edges assigned
# Shuffling 516 at 1.09%. 399/400 edges assigned
# Shuffling 517 at 1.10%. 399/400 edges assigned
# Shuffling 518 at 1.12%. 399/400 edges assigned
# Shuffling 519 at 1.13%. 399/400 edges assigned
# Shuffling 520 at 1.14%. 399/400 edges assigned
# Shuffling 521 at 1.15%. 399/400 edges assigned
# Shuffling 522 at 1.16%. 399/400 edges assigned
# Shuffling 523 at 1.17%. 399/400 edges assigned
# Shuffling 524 at 1.18%. 399/400 edges assigned
# Shuffling 525 at 1.20%. 399/400 edges assigned
# Shuffling 526 at 1.21%. 399/400 edges assigned
# Shuffling 527 at 1.22%. 399/400 edges assigned
# Shuffling 528 at 1.23%. 399/400 edges assigned
# Shuffling 529 at 1.24%. 399/400 edges assigned
# Shuffling 530 at 1.26%. 399/400 edges assigned
# Shuffling 531 at 1.27%. 399/400 edges assigned
# Shuffling 532 at 1.28%. 399/400 edges assigned
# Shuffling 533 at 1.30%. 399/400 edges assigned
# Shuffling 534 at 1.31%. 399/400 edges assigned
# Shuffling 535 at 1.32%. 399/400 edges assigned
# Shuffling 536 at 1.33%. 399/400 edges assigned
# Shuffling 537 at 1.35%. 399/400 edges assigned
# Shuffling 538 at 1.36%. 399/400 edges assigned
# Shuffling 539 at 1.37%. 399/400 edges assigned
# Shuffling 540 at 1.39%. 399/400 edges assigned
# Shuffling 541 at 1.40%. 399/400 edges assigned
# Shuffling 542 at 1.42%. 399/400 edges assigned
# Shuffling 543 at 1.43%. 399/400 edges assigned
# Shuffling 544 at 1.45%. 399/400 edges assigned
# Shuffling 545 at 1.46%. 399/400 edges assigned
# Shuffling 546 at 1.47%. 399/400 edges assigned
# Shuffling 547 at 1.49%. 399/400 edges assigned
# Shuffling 548 at 1.50%. 399/400 edges assigned
# Shuffling 549 at 1.52%. 399/400 edges assigned
# Shuffling 550 at 1.53%. 399/400 edges assigned
# Shuffling 551 at 1.55%. 399/400 edges assigned
# Shuffling 552 at 1.56%. 399/400 edges assigned
# Shuffling 553 at 1.58%. 399/400 edges assigned
# Shuffling 554 at 1.60%. 399/400 edges assigned
# Shuffling 555 at 1.61%. 399/400 edges assigned
# Shuffling 556 at 1.63%. 399/400 edges assigned
# Shuffling 557 at 1.64%. 399/400 edges assigned
# Shuffling 558 at 1.66%. 399/400 edges assigned
# Shuffling 559 at 1.68%. 399/400 edges assigned
# Shuffling 560 at 1.69%. 399/400 edges assigned
# Shuffling 561 at 1.71%. 399/400 edges assigned
# Shuffling 562 at 1.73%. 399/400 edges assigned
# Shuffling 563 at 1.75%. 399/400 edges assigned
# Shuffling 564 at 1.76%. 399/400 edges assigned
# Shuffling 565 at 1.78%. 399/400 edges assigned
# Shuffling 566 at 1.80%. 399/400 edges assigned
# Shuffling 567 at 1.82%. 399/400 edges assigned
# Shuffling 568 at 1.83%. 399/400 edges assigned
# Shuffling 569 at 1.85%. 399/400 edges assigned
# Shuffling 570 at 1.87%. 399/400 edges assigned
# Shuffling 571 at 1.89%. 399/400 edges assigned
# Shuffling 572 at 1.91%. 399/400 edges assigned
# Shuffling 573 at 1.93%. 399/400 edges assigned
# Shuffling 574 at 1.95%. 399/400 edges assigned
# Shuffling 575 at 1.97%. 399/400 edges assigned
# Shuffling 576 at 1.99%. 399/400 edges assigned
# Shuffling 577 at 2.01%. 399/400 edges assigned
# Shuffling 578 at 2.03%. 399/400 edges assigned
# Shuffling 579 at 2.05%. 399/400 edges assigned
# Shuffling 580 at 2.07%. 399/400 edges assigned
# Shuffling 581 at 2.09%. 399/400 edges assigned
# Shuffling 582 at 2.11%. 399/400 edges assigned
# Shuffling 583 at 2.13%. 399/400 edges assigned
# Shuffling 584 at 2.15%. 399/400 edges assigned
# Shuffling 585 at 2.17%. 399/400 edges assigned
# Shuffling 586 at 2.19%. 399/400 edges assigned
# Shuffling 587 at 2.22%. 399/400 edges assigned
# Shuffling 588 at 2.24%. 399/400 edges assigned
# Shuffling 589 at 2.26%. 399/400 edges assigned
# Shuffling 590 at 2.28%. 399/400 edges assigned
# Shuffling 591 at 2.31%. 399/400 edges assigned
# Shuffling 592 at 2.33%. 399/400 edges assigned
# Shuffling 593 at 1.00%. 399/400 edges assigned
# Shuffling 594 at 1.01%. 399/400 edges assigned
# Shuffling 595 at 1.02%. 399/400 edges assigned
# Shuffling 596 at 1.03%. 399/400 edges assigned
# Shuffling 597 at 1.04%. 399/400 edges assigned
# Shuffling 598 at 1.05%. 399/400 edges assigned
# Shuffling 599 at 1.06%. 399/400 edges assigned
# Shuffling 600 at 1.07%. 399/400 edges assigned
# Shuffling 601 at 1.08%. 399/400 edges assigned
# Shuffling 602 at 1.09%. 399/400 edges assigned
# Shuffling 603 at 1.10%. 399/400 edges assigned
# Shuffling 604 at 1.00%. 399/400 edges assigned
# Shuffling 605 at 1.01%. 399/400 edges assigned
# Shuffling 606 at 1.02%. 399/400 edges assigned
# Shuffling 607 at 1.03%. 399/400 edges assigned
# Shuffling 608 at 1.04%. 399/400 edges assigned
# Shuffling 609 at 1.05%. 399/400 edges assigned
# Shuffling 610 at 1.06%. 399/400 edges assigned
# Shuffling 611 at 1.07%. 399/400 edges assigned
# Shuffling 612 at 1.08%. 399/400 edges assigned
# Shuffling 613 at 1.09%. 399/400 edges assigned
# Shuffling 614 at 1.10%. 399/400 edges assigned
# Shuffling 615 at 1.12%. 399/400 edges assigned
# Shuffling 616 at 1.13%. 399/400 edges assigned
# Shuffling 617 at 1.14%. 399/400 edges assigned
# Shuffling 618 at 1.15%. 399/400 edges assigned
# Shuffling 619 at 1.16%. 399/400 edges assigned
# Shuffling 620 at 1.17%. 399/400 edges assigned
# Shuffling 621 at 1.18%. 399/400 edges assigned
# Shuffling 622 at 1.20%. 399/400 edges assigned
# Shuffling 623 at 1.21%. 399/400 edges assigned
# Shuffling 624 at 1.22%. 399/400 edges assigned
# Shuffling 625 at 1.23%. 399/400 edges assigned
# Shuffling 626 at 1.00%. 399/400 edges assigned
# Shuffling 627 at 1.00%. 399/400 edges assigned
# Shuffling 628 at 1.00%. 399/400 edges assigned
# Shuffling 629 at 1.01%. 399/400 edges assigned
# Shuffling 630 at 1.02%. 399/400 edges assigned
# Shuffling 631 at 1.00%. 399/400 edges assigned
# Shuffling 632 at 1.00%. 399/400 edges assigned
# Shuffling 633 at 1.00%. 399/400 edges assigned
# Shuffling 634 at 1.00%. 399/400 edges assigned
# Shuffling 635 at 1.01%. 399/400 edges assigned
# Shuffling 636 at 1.02%. 399/400 edges assigned
# Shuffling 637 at 1.03%. 399/400 edges assigned
# Shuffling 638 at 1.04%. 399/400 edges assigned
# Shuffling 639 at 1.00%. 399/400 edges assigned
# Shuffling 640 at 1.01%. 399/400 edges assigned
# Shuffling 641 at 1.02%. 399/400 edges assigned
# Shuffling 642 at 1.00%. 399/400 edges assigned
# Shuffling 643 at 1.00%. 399/400 edges assigned
# Shuffling 644 at 1.01%. 399/400 edges assigned
# Shuffling 645 at 1.02%. 399/400 edges assigned
# Shuffling 646 at 1.03%. 399/400 edges assigned
# Shuffling 647 at 1.04%. 399/400 edges assigned
# Shuffling 648 at 1.05%. 399/400 edges assigned
# Shuffling 649 at 1.06%. 399/400 edges assigned
# Shuffling 650 at 1.07%. 399/400 edges assigned
# Shuffling 651 at 1.08%. 399/400 edges assigned
# Shuffling 652 at 1.00%. 399/400 edges assigned
# Shuffling 653 at 1.01%. 399/400 edges assigned
# Shuffling 654 at 1.02%. 399/400 edges assigned
# Shuffling 655 at 1.03%. 399/400 edges assigned
# Shuffling 656 at 1.04%. 399/400 edges assigned
# Shuffling 657 at 1.05%. 399/400 edges assigned
# Shuffling 658 at 1.06%. 399/400 edges assigned
# Shuffling 659 at 1.07%. 399/400 edges assigned
# Shuffling 660 at 1.08%. 399/400 edges assigned
# Shuffling 661 at 1.09%. 399/400 edges assigned
# Shuffling 662 at 1.10%. 399/400 edges assigned
# Shuffling 663 at 1.00%. 399/400 edges assigned
# Shuffling 664 at 1.01%. 399/400 edges assigned
# Shuffling 665 at 1.02%. 399/400 edges assigned
# Shuffling 666 at 1.03%. 399/400 edges assigned
# Shuffling 667 at 1.04%. 399/400 edges assigned
# Shuffling 668 at 1.05%. 399/400 edges assigned
# Shuffling 669 at 1.06%. 399/400 edges assigned
# Shuffling 670 at 1.07%. 399/400 edges assigned
# Shuffling 671 at 1.08%. 399/400 edges assigned
# Shuffling 672 at 1.09%. 399/400 edges assigned
# Shuffling 673 at 1.10%. 399/400 edges assigned
# Shuffling 674 at 1.12%. 399/400 edges assigned
# Shuffling 675 at 1.13%. 399/400 edges assigned
# Shuffling 676 at 1.14%. 399/400 edges assigned
# Shuffling 677 at 1.15%. 399/400 edges assigned
# Shuffling 678 at 1.16%. 399/400 edges assigned
# Shuffling 679 at 1.17%. 399/400 edges assigned
# Shuffling 680 at 1.18%. 399/400 edges assigned
# Shuffling 681 at 1.20%. 399/400 edges assigned
# Shuffling 682 at 1.21%. 399/400 edges assigned
# Shuffling 683 at 1.22%. 399/400 edges assigned
# Shuffling 684 at 1.23%. 399/400 edges assigned
# Shuffling 685 at 1.24%. 399/400 edges assigned
# Shuffling 686 at 1.26%. 399/400 edges assigned
# Shuffling 687 at 1.27%. 399/400 edges assigned
# Shuffling 688 at 1.28%. 399/400 edges assigned
# Shuffling 689 at 1.30%. 399/400 edges assigned
# Shuffling 690 at 1.31%. 399/400 edges assigned
# Shuffling 691 at 1.32%. 399/400 edges assigned
# Shuffling 692 at 1.33%. 399/400 edges assigned
# Shuffling 693 at 1.35%. 399/400 edges assigned
# Shuffling 694 at 1.36%. 399/400 edges assigned
# Shuffling 695 at 1.37%. 399/400 edges assigned
# Shuffling 696 at 1.00%. 399/400 edges assigned
# Shuffling 697 at 1.00%. 399/400 edges assigned
# Shuffling 698 at 1.01%. 399/400 edges assigned
# Shuffling 699 at 1.02%. 399/400 edges assigned
# Shuffling 700 at 1.00%. 399/400 edges assigned
# Shuffling 701 at 1.00%. 399/400 edges assigned
# Shuffling 702 at 1.01%. 399/400 edges assigned
# Shuffling 703 at 1.02%. 399/400 edges assigned
# Shuffling 704 at 1.03%. 399/400 edges assigned
# Shuffling 705 at 1.04%. 399/400 edges assigned
# Shuffling 706 at 1.05%. 399/400 edges assigned
# Shuffling 707 at 1.06%. 399/400 edges assigned
# Shuffling 708 at 1.07%. 399/400 edges assigned
# Shuffling 709 at 1.08%. 399/400 edges assigned
# Shuffling 710 at 1.09%. 399/400 edges assigned
# Shuffling 711 at 1.10%. 399/400 edges assigned
# Shuffling 712 at 1.12%. 399/400 edges assigned
# Shuffling 713 at 1.13%. 399/400 edges assigned
# Shuffling 714 at 1.14%. 399/400 edges assigned
# Shuffling 715 at 1.15%. 399/400 edges assigned
# Shuffling 716 at 1.16%. 399/400 edges assigned
# Shuffling 717 at 1.17%. 399/400 edges assigned
# Shuffling 718 at 1.18%. 399/400 edges assigned
# Shuffling 719 at 1.20%. 399/400 edges assigned
# Shuffling 720 at 1.21%. 399/400 edges assigned
# Shuffling 721 at 1.22%. 399/400 edges assigned
# Shuffling 722 at 1.23%. 399/400 edges assigned
# Shuffling 723 at 1.24%. 399/400 edges assigned
# Shuffling 724 at 1.26%. 399/400 edges assigned
# Shuffling 725 at 1.27%. 399/400 edges assigned
# Shuffling 726 at 1.00%. 399/400 edges assigned
# Shuffling 727 at 1.00%. 399/400 edges assigned
# Shuffling 728 at 1.01%. 399/400 edges assigned
# Shuffling 729 at 1.02%. 399/400 edges assigned
# Shuffling 730 at 1.03%. 399/400 edges assigned
# Shuffling 731 at 1.04%. 399/400 edges assigned
# Shuffling 732 at 1.05%. 399/400 edges assigned
# Shuffling 733 at 1.06%. 399/400 edges assigned
# Shuffling 734 at 1.07%. 399/400 edges assigned
# Shuffling 735 at 1.08%. 399/400 edges assigned
# Shuffling 736 at 1.09%. 399/400 edges assigned
# Shuffling 737 at 1.10%. 399/400 edges assigned
# Shuffling 738 at 1.12%. 399/400 edges assigned
# Shuffling 739 at 1.13%. 399/400 edges assigned
# Shuffling 740 at 1.14%. 399/400 edges assigned
# Shuffling 741 at 1.15%. 399/400 edges assigned
# Shuffling 742 at 1.16%. 399/400 edges assigned
# Shuffling 743 at 1.17%. 399/400 edges assigned
# Shuffling 744 at 1.18%. 399/400 edges assigned
# Shuffling 745 at 1.20%. 399/400 edges assigned
# Shuffling 746 at 1.21%. 399/400 edges assigned
# Shuffling 747 at 1.22%. 399/400 edges assigned
# Shuffling 748 at 1.23%. 399/400 edges assigned
# Shuffling 749 at 1.24%. 399/400 edges assigned
# Shuffling 750 at 1.26%. 399/400 edges assigned
# Shuffling 751 at 1.27%. 399/400 edges assigned
# Shuffling 752 at 1.28%. 399/400 edges assigned
# Shuffling 753 at 1.30%. 399/400 edges assigned
# Shuffling 754 at 1.31%. 399/400 edges assigned
# Shuffling 755 at 1.32%. 399/400 edges assigned
# Shuffling 756 at 1.33%. 399/400 edges assigned
# Shuffling 757 at 1.35%. 399/400 edges assigned
# Shuffling 758 at 1.00%. 399/400 edges assigned
# Shuffling 759 at 1.00%. 399/400 edges assigned
# Shuffling 760 at 1.01%. 399/400 edges assigned
# Shuffling 761 at 1.02%. 399/400 edges assigned
# Shuffling 762 at 1.03%. 399/400 edges assigned
# Shuffling 763 at 1.04%. 399/400 edges assigned
# Shuffling 764 at 1.05%. 399/400 edges assigned
# Shuffling 765 at 1.06%. 399/400 edges assigned
# Shuffling 766 at 1.07%. 399/400 edges assigned
# Shuffling 767 at 1.08%. 399/400 edges assigned
# Shuffling 768 at 1.09%. 399/400 edges assigned
# Shuffling 769 at 1.10%. 399/400 edges assigned
# Shuffling 770 at 1.12%. 399/400 edges assigned
# Shuffling 771 at 1.13%. 399/400 edges assigned
# Shuffling 772 at 1.14%. 399/400 edges assigned
# Shuffling 773 at 1.15%. 399/400 edges assigned
# Shuffling 774 at 1.16%. 399/400 edges assigned
# Shuffling 775 at 1.17%. 399/400 edges assigned
# Shuffling 776 at 1.18%. 399/400 edges assigned
# Shuffling 777 at 1.20%. 399/400 edges assigned
# Shuffling 778 at 1.21%. 399/400 edges assigned
# Shuffling 779 at 1.22%. 399/400 edges assigned
# Shuffling 780 at 1.23%. 399/400 edges assigned
# Shuffling 781 at 1.24%. 399/400 edges assigned
# Shuffling 782 at 1.26%. 399/400 edges assigned
# Shuffling 783 at 1.27%. 399/400 edges assigned
# Shuffling 784 at 1.28%. 399/400 edges assigned
# Shuffling 785 at 1.30%. 399/400 edges assigned
# Shuffling 786 at 1.31%. 399/400 edges assigned
# Shuffling 787 at 1.32%. 399/400 edges assigned
# Shuffling 788 at 1.33%. 399/400 edges assigned
# Shuffling 789 at 1.35%. 399/400 edges assigned
# Shuffling 790 at 1.36%. 399/400 edges assigned
# Shuffling 791 at 1.37%. 399/400 edges assigned
# Shuffling 792 at 1.39%. 399/400 edges assigned
# Shuffling 793 at 1.40%. 399/400 edges assigned
# Shuffling 794 at 1.42%. 399/400 edges assigned
# Shuffling 795 at 1.43%. 399/400 edges assigned
# Shuffling 796 at 1.45%. 399/400 edges assigned
# ...
# Shuffling 157 at 2.55%. 1599/1600 edges assigned
# Shuffling 158 at 2.57%. 1599/1600 edges assigned
# Shuffling 159 at 2.60%. 1599/1600 edges assigned
# Shuffling 160 at 2.63%. 1599/1600 edges assigned
# Shuffling 161 at 2.65%. 1599/1600 edges assigned
# Shuffling 162 at 2.68%. 1599/1600 edges assigned
# Shuffling 163 at 2.70%. 1599/1600 edges assigned
# Shuffling 164 at 2.73%. 1599/1600 edges assigned
# Shuffling 165 at 2.76%. 1599/1600 edges assigned
# Shuffling 166 at 2.79%. 1599/1600 edges assigned
# Shuffling 167 at 2.81%. 1599/1600 edges assigned
# Shuffling 168 at 2.84%. 1599/1600 edges assigned
# Shuffling 169 at 2.87%. 1599/1600 edges assigned
# Shuffling 170 at 2.90%. 1599/1600 edges assigned
# Shuffling 171 at 2.93%. 1599/1600 edges assigned
# Shuffling 172 at 2.96%. 1599/1600 edges assigned
# Shuffling 173 at 2.99%. 1599/1600 edges assigned
# Shuffling 174 at 3.02%. 1599/1600 edges assigned
# Shuffling 175 at 3.05%. 1599/1600 edges assigned
# Shuffling 176 at 3.08%. 1599/1600 edges assigned
# Shuffling 177 at 3.11%. 1599/1600 edges assigned
# Shuffling 178 at 3.14%. 1599/1600 edges assigned
# Shuffling 179 at 3.17%. 1599/1600 edges assigned
# Shuffling 180 at 3.20%. 1599/1600 edges assigned
# Shuffling 181 at 3.24%. 1599/1600 edges assigned
# Shuffling 182 at 3.27%. 1599/1600 edges assigned
# Shuffling 183 at 3.30%. 1599/1600 edges assigned
# Shuffling 184 at 3.33%. 1599/1600 edges assigned
# Shuffling 185 at 3.37%. 1599/1600 edges assigned
# Shuffling 186 at 3.40%. 1599/1600 edges assigned
# Shuffling 187 at 3.43%. 1599/1600 edges assigned
# Shuffling 188 at 3.47%. 1599/1600 edges assigned
# Shuffling 189 at 3.50%. 1599/1600 edges assigned
# Shuffling 190 at 3.54%. 1599/1600 edges assigned
# Shuffling 191 at 3.57%. 1599/1600 edges assigned
# Shuffling 192 at 3.61%. 1599/1600 edges assigned
# Shuffling 193 at 3.65%. 1599/1600 edges assigned
# Shuffling 194 at 3.68%. 1599/1600 edges assigned
# Shuffling 195 at 3.72%. 1599/1600 edges assigned
# Shuffling 196 at 3.76%. 1599/1600 edges assigned
# Shuffling 197 at 3.79%. 1599/1600 edges assigned
# Shuffling 198 at 3.83%. 1599/1600 edges assigned
# Shuffling 199 at 3.87%. 1599/1600 edges assigned
# Shuffling 200 at 3.91%. 1599/1600 edges assigned
# Shuffling 201 at 3.95%. 1599/1600 edges assigned
# Shuffling 202 at 3.99%. 1599/1600 edges assigned
# Shuffling 203 at 4.03%. 1599/1600 edges assigned
# Shuffling 204 at 4.07%. 1599/1600 edges assigned
# Shuffling 205 at 4.11%. 1599/1600 edges assigned
# Shuffling 206 at 4.15%. 1599/1600 edges assigned
# Shuffling 207 at 4.19%. 1599/1600 edges assigned
# Shuffling 208 at 4.23%. 1599/1600 edges assigned
# Shuffling 209 at 4.27%. 1599/1600 edges assigned
# Shuffling 210 at 4.32%. 1599/1600 edges assigned
# Shuffling 211 at 4.36%. 1599/1600 edges assigned
# Shuffling 212 at 4.40%. 1599/1600 edges assigned
# Shuffling 213 at 4.45%. 1599/1600 edges assigned
# Shuffling 214 at 4.49%. 1599/1600 edges assigned
# Shuffling 215 at 4.54%. 1599/1600 edges assigned
# Shuffling 216 at 4.58%. 1599/1600 edges assigned
# Shuffling 217 at 4.63%. 1599/1600 edges assigned
# Shuffling 218 at 4.68%. 1599/1600 edges assigned
# Shuffling 219 at 4.72%. 1599/1600 edges assigned
# Shuffling 220 at 4.77%. 1599/1600 edges assigned
# Shuffling 221 at 4.82%. 1599/1600 edges assigned
# Shuffling 222 at 4.87%. 1599/1600 edges assigned
# Shuffling 223 at 4.91%. 1599/1600 edges assigned
# Shuffling 224 at 4.96%. 1599/1600 edges assigned
# Shuffling 225 at 5.01%. 1599/1600 edges assigned
# Shuffling 226 at 5.06%. 1599/1600 edges assigned
# Shuffling 227 at 5.11%. 1599/1600 edges assigned
# Shuffling 228 at 5.16%. 1599/1600 edges assigned
# Shuffling 229 at 5.22%. 1599/1600 edges assigned
# Shuffling 230 at 5.27%. 1599/1600 edges assigned
# Shuffling 231 at 5.32%. 1599/1600 edges assigned
# Shuffling 232 at 5.37%. 1599/1600 edges assigned
# Shuffling 233 at 5.43%. 1599/1600 edges assigned
# Shuffling 234 at 5.48%. 1599/1600 edges assigned
# Shuffling 235 at 5.54%. 1599/1600 edges assigned
# Shuffling 236 at 5.59%. 1599/1600 edges assigned
# Shuffling 237 at 5.65%. 1599/1600 edges assigned
# Shuffling 238 at 5.70%. 1599/1600 edges assigned
# Shuffling 239 at 5.76%. 1599/1600 edges assigned
# Shuffling 240 at 5.82%. 1599/1600 edges assigned
# Shuffling 241 at 5.88%. 1599/1600 edges assigned
# Shuffling 242 at 5.94%. 1599/1600 edges assigned
# Shuffling 243 at 6.00%. 1599/1600 edges assigned
# Shuffling 244 at 6.06%. 1599/1600 edges assigned
# Shuffling 245 at 6.12%. 1599/1600 edges assigned
# Shuffling 246 at 6.18%. 1599/1600 edges assigned
# Shuffling 247 at 6.24%. 1599/1600 edges assigned
# Shuffling 248 at 6.30%. 1599/1600 edges assigned
# Shuffling 249 at 6.36%. 1599/1600 edges assigned
# Shuffling 250 at 6.43%. 1599/1600 edges assigned
# Shuffling 251 at 6.49%. 1599/1600 edges assigned
# Shuffling 252 at 6.56%. 1599/1600 edges assigned
# Shuffling 253 at 6.62%. 1599/1600 edges assigned
# Shuffling 254 at 6.69%. 1599/1600 edges assigned
# Shuffling 255 at 6.76%. 1599/1600 edges assigned
# Shuffling 256 at 6.82%. 1599/1600 edges assigned
# Shuffling 257 at 6.89%. 1599/1600 edges assigned
# Shuffling 258 at 6.96%. 1599/1600 edges assigned
# Shuffling 259 at 7.03%. 1599/1600 edges assigned
# Shuffling 260 at 7.10%. 1599/1600 edges assigned
# Shuffling 261 at 7.17%. 1599/1600 edges assigned
# Shuffling 262 at 7.24%. 1599/1600 edges assigned
# Shuffling 263 at 7.32%. 1599/1600 edges assigned
# Shuffling 264 at 7.39%. 1599/1600 edges assigned
# Shuffling 265 at 7.46%. 1599/1600 edges assigned
# Shuffling 266 at 7.54%. 1599/1600 edges assigned
# Shuffling 267 at 7.61%. 1599/1600 edges assigned
# Shuffling 268 at 7.69%. 1599/1600 edges assigned
# Shuffling 269 at 7.77%. 1599/1600 edges assigned
# Shuffling 270 at 7.84%. 1599/1600 edges assigned
# Shuffling 271 at 7.92%. 1599/1600 edges assigned
# Shuffling 272 at 8.00%. 1599/1600 edges assigned
# Shuffling 273 at 8.08%. 1599/1600 edges assigned
# Shuffling 274 at 8.16%. 1599/1600 edges assigned
# Shuffling 275 at 8.24%. 1599/1600 edges assigned
# Shuffling 276 at 8.33%. 1599/1600 edges assigned
# Shuffling 277 at 8.41%. 1599/1600 edges assigned
# Shuffling 278 at 8.49%. 1599/1600 edges assigned
# Shuffling 279 at 8.58%. 1599/1600 edges assigned
# Shuffling 280 at 8.66%. 1599/1600 edges assigned
# Shuffling 281 at 8.75%. 1599/1600 edges assigned
# Shuffling 282 at 8.84%. 1599/1600 edges assigned
# Shuffling 283 at 8.93%. 1599/1600 edges assigned
# Shuffling 284 at 9.02%. 1599/1600 edges assigned
# Shuffling 285 at 9.11%. 1599/1600 edges assigned
# Shuffling 286 at 9.20%. 1599/1600 edges assigned
# Shuffling 287 at 9.29%. 1599/1600 edges assigned
# Shuffling 288 at 9.38%. 1599/1600 edges assigned
# Shuffling 289 at 9.48%. 1599/1600 edges assigned
# Shuffling 290 at 9.57%. 1599/1600 edges assigned
# Shuffling 291 at 9.67%. 1599/1600 edges assigned
# Shuffling 292 at 9.76%. 1599/1600 edges assigned
# Shuffling 293 at 9.86%. 1599/1600 edges assigned
# Shuffling 294 at 9.96%. 1599/1600 edges assigned
# Shuffling 295 at 10.06%. 1599/1600 edges assigned
# Shuffling 296 at 10.16%. 1599/1600 edges assigned
# Shuffling 297 at 10.26%. 1599/1600 edges assigned
# Shuffling 298 at 10.36%. 1599/1600 edges assigned
# Shuffling 299 at 10.47%. 1599/1600 edges assigned
# Shuffling 300 at 10.57%. 1599/1600 edges assigned
# Shuffling 301 at 10.68%. 1599/1600 edges assigned
# Shuffling 302 at 10.78%. 1599/1600 edges assigned
# Shuffling 303 at 10.89%. 1599/1600 edges assigned
# Shuffling 304 at 11.00%. 1599/1600 edges assigned
# Shuffling 305 at 11.11%. 1599/1600 edges assigned
# Shuffling 306 at 11.22%. 1599/1600 edges assigned
# Shuffling 307 at 11.33%. 1599/1600 edges assigned
# Shuffling 308 at 11.45%. 1599/1600 edges assigned
# Shuffling 309 at 11.56%. 1599/1600 edges assigned
# Shuffling 310 at 11.68%. 1599/1600 edges assigned
# Shuffling 311 at 11.80%. 1599/1600 edges assigned
# Shuffling 312 at 11.91%. 1599/1600 edges assigned
# Shuffling 313 at 12.03%. 1599/1600 edges assigned
# Shuffling 314 at 12.15%. 1599/1600 edges assigned
# Shuffling 315 at 12.27%. 1599/1600 edges assigned
# Shuffling 316 at 12.40%. 1599/1600 edges assigned
# Shuffling 317 at 12.52%. 1599/1600 edges assigned
# Shuffling 318 at 12.65%. 1599/1600 edges assigned
# Shuffling 319 at 12.77%. 1599/1600 edges assigned
# Shuffling 320 at 12.90%. 1599/1600 edges assigned
# Shuffling 321 at 13.03%. 1599/1600 edges assigned
# Shuffling 322 at 13.16%. 1599/1600 edges assigned
# Shuffling 323 at 13.29%. 1599/1600 edges assigned
# Shuffling 324 at 13.42%. 1599/1600 edges assigned
# Shuffling 325 at 13.56%. 1599/1600 edges assigned
# Shuffling 326 at 13.69%. 1599/1600 edges assigned
# Shuffling 327 at 13.83%. 1599/1600 edges assigned
# Shuffling 328 at 13.97%. 1599/1600 edges assigned
# Shuffling 329 at 14.11%. 1599/1600 edges assigned
# Shuffling 330 at 14.25%. 1599/1600 edges assigned
# Shuffling 331 at 14.39%. 1599/1600 edges assigned
# Shuffling 332 at 14.54%. 1599/1600 edges assigned
# Shuffling 333 at 14.68%. 1599/1600 edges assigned
# Shuffling 334 at 14.83%. 1599/1600 edges assigned
# Shuffling 335 at 14.98%. 1599/1600 edges assigned
# Shuffling 336 at 15.13%. 1599/1600 edges assigned
# Shuffling 337 at 15.28%. 1599/1600 edges assigned
# Shuffling 338 at 15.43%. 1599/1600 edges assigned
# Shuffling 339 at 15.58%. 1599/1600 edges assigned
# Shuffling 340 at 15.74%. 1599/1600 edges assigned
# Shuffling 341 at 15.90%. 1599/1600 edges assigned
# Shuffling 342 at 16.06%. 1599/1600 edges assigned
# Shuffling 343 at 16.22%. 1599/1600 edges assigned
# Shuffling 344 at 16.38%. 1599/1600 edges assigned
# Shuffling 345 at 16.54%. 1599/1600 edges assigned
# Shuffling 346 at 16.71%. 1599/1600 edges assigned
# Shuffling 347 at 16.88%. 1599/1600 edges assigned
# Shuffling 348 at 17.04%. 1599/1600 edges assigned
# Shuffling 349 at 17.22%. 1599/1600 edges assigned
# Shuffling 350 at 17.39%. 1599/1600 edges assigned
# Shuffling 351 at 17.56%. 1599/1600 edges assigned
# Shuffling 352 at 17.74%. 1599/1600 edges assigned
# Shuffling 353 at 17.91%. 1599/1600 edges assigned
# Shuffling 354 at 18.09%. 1599/1600 edges assigned
# Shuffling 355 at 18.27%. 1599/1600 edges assigned
# Shuffling 356 at 18.46%. 1599/1600 edges assigned
# Shuffling 357 at 18.64%. 1599/1600 edges assigned
# Shuffling 358 at 18.83%. 1599/1600 edges assigned
# Shuffling 359 at 19.02%. 1599/1600 edges assigned
# Shuffling 360 at 19.21%. 1599/1600 edges assigned
# Shuffling 361 at 19.40%. 1599/1600 edges assigned
# Shuffling 362 at 19.59%. 1599/1600 edges assigned
# Shuffling 363 at 19.79%. 1599/1600 edges assigned
# Shuffling 364 at 19.99%. 1599/1600 edges assigned
# Shuffling 365 at 20.19%. 1599/1600 edges assigned
# Shuffling 366 at 20.39%. 1599/1600 edges assigned
# Shuffling 367 at 20.59%. 1599/1600 edges assigned
# Shuffling 368 at 20.80%. 1599/1600 edges assigned
# Shuffling 369 at 21.01%. 1599/1600 edges assigned
# Shuffling 370 at 21.22%. 1599/1600 edges assigned
# Shuffling 371 at 21.43%. 1599/1600 edges assigned
# Shuffling 372 at 21.64%. 1599/1600 edges assigned
# Shuffling 373 at 21.86%. 1599/1600 edges assigned
# Shuffling 374 at 22.08%. 1599/1600 edges assigned
# Shuffling 375 at 22.30%. 1599/1600 edges assigned
# Shuffling 376 at 22.52%. 1599/1600 edges assigned
# Shuffling 377 at 22.75%. 1599/1600 edges assigned
# Shuffling 378 at 22.97%. 1599/1600 edges assigned
# Shuffling 379 at 23.20%. 1599/1600 edges assigned
# Shuffling 380 at 23.44%. 1599/1600 edges assigned
# Shuffling 381 at 23.67%. 1599/1600 edges assigned
# Shuffling 382 at 23.91%. 1599/1600 edges assigned
# Shuffling 383 at 24.15%. 1599/1600 edges assigned
# Shuffling 384 at 24.39%. 1599/1600 edges assigned
# Shuffling 385 at 24.63%. 1599/1600 edges assigned
# Shuffling 386 at 24.88%. 1599/1600 edges assigned
# Shuffling 387 at 25.13%. 1599/1600 edges assigned
# Shuffling 388 at 25.38%. 1599/1600 edges assigned
# Shuffling 389 at 25.63%. 1599/1600 edges assigned
# Shuffling 390 at 25.89%. 1599/1600 edges assigned
# Shuffling 391 at 26.15%. 1599/1600 edges assigned
# Shuffling 392 at 26.41%. 1599/1600 edges assigned
# Shuffling 393 at 26.67%. 1599/1600 edges assigned
# Shuffling 394 at 26.94%. 1599/1600 edges assigned
# Shuffling 395 at 27.21%. 1599/1600 edges assigned
# Shuffling 396 at 27.48%. 1599/1600 edges assigned
# Shuffling 397 at 27.75%. 1599/1600 edges assigned
# Shuffling 398 at 28.03%. 1599/1600 edges assigned
# Shuffling 399 at 28.31%. 1599/1600 edges assigned
# Shuffling 400 at 28.60%. 1599/1600 edges assigned
# Shuffling 401 at 28.88%. 1599/1600 edges assigned
# Shuffling 402 at 29.17%. 1599/1600 edges assigned
# Shuffling 403 at 29.46%. 1599/1600 edges assigned
# Shuffling 404 at 29.76%. 1599/1600 edges assigned
# Shuffling 405 at 30.05%. 1599/1600 edges assigned
# Shuffling 406 at 30.36%. 1599/1600 edges assigned
# Shuffling 407 at 30.66%. 1599/1600 edges assigned
# Shuffling 408 at 30.97%. 1599/1600 edges assigned
# Shuffling 409 at 31.27%. 1599/1600 edges assigned
# Shuffling 410 at 31.59%. 1599/1600 edges assigned
# Shuffling 411 at 31.90%. 1599/1600 edges assigned
# Shuffling 412 at 32.22%. 1599/1600 edges assigned
# Shuffling 413 at 32.54%. 1599/1600 edges assigned
# Shuffling 414 at 32.87%. 1599/1600 edges assigned
# Shuffling 415 at 33.20%. 1599/1600 edges assigned
# Shuffling 416 at 33.53%. 1599/1600 edges assigned
# Shuffling 417 at 33.87%. 1599/1600 edges assigned
# Shuffling 418 at 34.20%. 1599/1600 edges assigned
# Shuffling 419 at 34.55%. 1599/1600 edges assigned
# Shuffling 420 at 34.89%. 1599/1600 edges assigned
# Shuffling 421 at 35.24%. 1599/1600 edges assigned
# Shuffling 422 at 35.59%. 1599/1600 edges assigned
# Shuffling 423 at 35.95%. 1599/1600 edges assigned
# Shuffling 424 at 36.31%. 1599/1600 edges assigned
# Shuffling 425 at 36.67%. 1599/1600 edges assigned
# Shuffling 426 at 37.04%. 1599/1600 edges assigned
# Shuffling 427 at 37.41%. 1599/1600 edges assigned
# Shuffling 428 at 37.78%. 1599/1600 edges assigned
# Shuffling 429 at 38.16%. 1599/1600 edges assigned
# Shuffling 430 at 38.54%. 1599/1600 edges assigned
# Shuffling 431 at 38.93%. 1599/1600 edges assigned
# Shuffling 432 at 39.32%. 1599/1600 edges assigned
# Shuffling 433 at 39.71%. 1599/1600 edges assigned
# Shuffling 434 at 40.11%. 1599/1600 edges assigned
# Shuffling 435 at 40.51%. 1599/1600 edges assigned
# Shuffling 436 at 40.91%. 1599/1600 edges assigned
# Shuffling 437 at 41.32%. 1599/1600 edges assigned
# Shuffling 438 at 41.74%. 1599/1600 edges assigned
# Shuffling 439 at 42.15%. 1599/1600 edges assigned
# Shuffling 440 at 42.58%. 1599/1600 edges assigned
# Shuffling 441 at 43.00%. 1599/1600 edges assigned
# Shuffling 442 at 43.43%. 1599/1600 edges assigned
# Shuffling 443 at 43.87%. 1599/1600 edges assigned
# Shuffling 444 at 44.30%. 1599/1600 edges assigned
# Shuffling 445 at 44.75%. 1599/1600 edges assigned
# Shuffling 446 at 45.19%. 1599/1600 edges assigned
# Shuffling 447 at 45.65%. 1599/1600 edges assigned
# Shuffling 448 at 46.10%. 1599/1600 edges assigned
# Shuffling 449 at 46.56%. 1599/1600 edges assigned
# Shuffling 450 at 47.03%. 1599/1600 edges assigned
# Shuffling 451 at 47.50%. 1599/1600 edges assigned
# Shuffling 452 at 47.97%. 1599/1600 edges assigned
# Shuffling 453 at 48.45%. 1599/1600 edges assigned
# Shuffling 454 at 48.94%. 1599/1600 edges assigned
# Shuffling 455 at 49.43%. 1599/1600 edges assigned
# Shuffling 456 at 49.92%. 1599/1600 edges assigned
# Shuffling 457 at 50.42%. 1599/1600 edges assigned
# Shuffling 458 at 50.93%. 1599/1600 edges assigned
# Shuffling 459 at 51.44%. 1599/1600 edges assigned
# Shuffling 460 at 51.95%. 1599/1600 edges assigned
# Shuffling 461 at 52.47%. 1599/1600 edges assigned
# Shuffling 462 at 52.99%. 1599/1600 edges assigned
# Shuffling 463 at 53.52%. 1599/1600 edges assigned
# Shuffling 464 at 54.06%. 1599/1600 edges assigned
# Shuffling 465 at 54.60%. 1599/1600 edges assigned
# Shuffling 466 at 55.15%. 1599/1600 edges assigned
# Shuffling 467 at 55.70%. 1599/1600 edges assigned
# Shuffling 468 at 56.25%. 1599/1600 edges assigned
# Shuffling 469 at 56.82%. 1599/1600 edges assigned
# Shuffling 470 at 57.39%. 1599/1600 edges assigned
# Shuffling 471 at 57.96%. 1599/1600 edges assigned
# Shuffling 472 at 58.54%. 1599/1600 edges assigned
# Shuffling 473 at 59.12%. 1599/1600 edges assigned
# Shuffling 474 at 59.72%. 1599/1600 edges assigned
# Shuffling 475 at 60.31%. 1599/1600 edges assigned
# Shuffling 476 at 60.92%. 1599/1600 edges assigned
# Shuffling 477 at 61.52%. 1599/1600 edges assigned
# Shuffling 478 at 62.14%. 1599/1600 edges assigned

# %% [markdown]
# ### Potential improvements
#
# * Derive mathematical condition for possible existnce of a regular subgraph.
# * Seems to struggle with `k > 3` and/or `k > j/2`.
# * Could try to find a better way to assign scores to edges, considering future graph structure (Monte Carlo?).
# * Could be smarter on which edges to remove when shuffling (/'backtracking'), some edges may preclude a solution so could permanently exclude them.
# * Amount of shuffling and rate of increase could be tuned.
# * Can be slow on larger graphs and larger `k`, mostly to do with shuffling repeats.
